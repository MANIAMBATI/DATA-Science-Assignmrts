# %%
import pandas as pd      
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
data=pd.read_csv(r"C:\Users\sai\OneDrive\Desktop\ToyotaCorolla - MLR.csv")
data
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
data.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
data.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
data.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df=data.drop(['KM'],axis=1)
df
# Out:
#       Price  Age_08_04 Fuel_Type   HP  Automatic    cc  Doors  Cylinders  \
# 0     13500         23    Diesel   90          0  2000      3          4
# 1     13750         23    Diesel   90          0  2000      3          4
# 2     13950         24    Diesel   90          0  2000      3          4
# 3     14950         26    Diesel   90          0  2000      3          4
# 4     13750         30    Diesel   90          0  2000      3          4
# ...     ...        ...       ...  ...        ...   ...    ...        ...
# 1431   7500         69    Petrol   86          0  1300      3          4
# 1432  10845         72    Petrol   86          0  1300      3          4
# 1433   8500         71    Petrol   86          0  1300      3          4
# 1434   7250         70    Petrol   86          0  1300      3          4
# 1435   6950         76    Petrol  110          0  1600      5          4
#
#       Gears  Weight
# 0         5    1165
# 1         5    1165
# 2         5    1165
# ...

# %%
correlation=df.corr(numeric_only=True)
correlation
# Out:
#               Price  Age_08_04        HP  Automatic        cc     Doors  \
# Price      1.000000  -0.876590  0.314990   0.033081  0.126389  0.185326
# Age_08_04 -0.876590   1.000000 -0.156622   0.031717 -0.098084 -0.148359
# HP         0.314990  -0.156622  1.000000   0.013144  0.035856  0.092424
# Automatic  0.033081   0.031717  0.013144   1.000000  0.066740 -0.027654
# cc         0.126389  -0.098084  0.035856   0.066740  1.000000  0.079903
# Doors      0.185326  -0.148359  0.092424  -0.027654  0.079903  1.000000
# Cylinders       NaN        NaN       NaN        NaN       NaN       NaN
# Gears      0.063104  -0.005364  0.209477  -0.098555  0.014629 -0.160141
# Weight     0.581198  -0.470253  0.089614   0.057249  0.335637  0.302618
#
#            Cylinders     Gears    Weight
# Price            NaN  0.063104  0.581198
# Age_08_04        NaN -0.005364 -0.470253
# HP               NaN  0.209477  0.089614
# Automatic        NaN -0.098555  0.057249
# ...

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc','Doors', 'Cylinders', 'Gears', 'Weight'],axis=1)
y=data['Price']
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,train_size=0.8)
x,y
# Out:
# (      Price
#  0     13500
#  1     13750
#  2     13950
#  3     14950
#  4     13750
#  ...     ...
#  1431   7500
#  1432  10845
#  1433   8500
#  1434   7250
#  1435   6950
#
#  [1436 rows x 1 columns],
#  0       13500
#  1       13750
#  2       13950
#  3       14950
#  4       13750
#          ...
#  1431     7500
#  1432    10845
#  1433     8500
#  1434     7250
#  1435     6950
#  Name: Price, Length: 1436, dtype: int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 model=LinearRegression
# ----> 2 model.fit(x_train,y_train)
#
# TypeError: LinearRegression.fit() missing 1 required positional argument: 'y'

# %%
r_sq=model.score(x_train,y_train)
print("coefficient of determination:",r_sq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 r_sq=model.score(x_train,y_train)
#       2 print("coefficient of determination:",r_sq)
#
# TypeError: RegressorMixin.score() missing 1 required positional argument: 'y'

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
data = pd.read_csv(r"C:\Users\PRJAWAL\OneDrive\Desktop\Excelr\Assignment-6\MLR\ToyotaCorolla - MLR.csv")
# Assuming your data has features in columns and the target variable in the last column
X = data.iloc[:, :-1]  # Features
y = data.iloc[:, -1]   # Target variable
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize a random forest classifier (you can choose any classifier)
classifier = RandomForestClassifier()

# Train the classifier
classifier.fit(x_train, y_train)

# Make predictions on the test set
predictions = classifier.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# Generate a classification report
report = classification_report(y_test, predictions)
print("\nClassification Report:")
print(report)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
# ----> 3 data = pd.read_csv(r"C:\Users\PRJAWAL\OneDrive\Desktop\Excelr\Assignment-6\MLR\ToyotaCorolla - MLR.csv")
#       4 # Assuming your data has features in columns and the target variable in the last column
#       5 X = data.iloc[:, :-1]  # Features
#
# ...
